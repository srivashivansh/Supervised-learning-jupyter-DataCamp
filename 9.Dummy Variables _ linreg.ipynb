# %%
import pandas as pd

# %%
df = pd.read_csv('auto-mpg.csv')

# %%
df_origin = pd.get_dummies(df)

# %%
print(df_origin.head())
# Out:
#     mpg  cylinders  ...  car name_vw rabbit c (diesel)  car name_vw rabbit custom
# 0  18.0          8  ...                              0                          0
# 1  15.0          8  ...                              0                          0
# 2  18.0          8  ...                              0                          0
# 3  16.0          8  ...                              0                          0
# 4  17.0          8  ...                              0                          0
#
# [5 rows x 406 columns]

# %%
df_origin = df_origin.drop('car name_vw rabbit c (diesel)', axis=1)

# %%
print(df_origin.head())
# Out:
#     mpg  cylinders  ...  car name_vw rabbit  car name_vw rabbit custom
# 0  18.0          8  ...                   0                          0
# 1  15.0          8  ...                   0                          0
# 2  18.0          8  ...                   0                          0
# 3  16.0          8  ...                   0                          0
# 4  17.0          8  ...                   0                          0
#
# [5 rows x 405 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8a2127e05083> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
#
# NameError: name 'X' is not defined

# %%
ridge = Ridge(alpha=0.5, normalize=True).fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-778e6323e946> in <module>()
# ----> 1 ridge = Ridge(alpha=0.5, normalize=True).fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
ridge..score(X_test, y_test)
# Out:
#   File "<ipython-input-13-eb24a552be49>", line 1
#     ridge..score(X_test, y_test)
#           ^
# SyntaxError: invalid syntax
