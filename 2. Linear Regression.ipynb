# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %%
boston = pd.read_csv('HousingData.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
 from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression

# %%
boston.isnull().sum()
boston.fillna(method='ffill',inplace=True)

# %%
X = boston.drop('MEDV' , axis=1).values

# %%
y = boston['MEDV'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
reg_all = LinearRegression()

# %%
reg_all.fit(X_train, y_train)
# X_train.shape
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg_all.predict(X_test)

# %%
y_pred
# Out:
# array([28.70292864, 36.6373768 , 15.46310266, 25.46132566, 18.84214686,
#        23.2125105 , 17.59903674, 14.11597466, 22.97200266, 20.70538766,
#        25.2094904 , 18.67555276, -6.71798079, 21.91273403, 19.27773445,
#        24.70965911, 20.04156773,  5.75815691, 40.19313854, 17.54637286,
#        23.99973474, 30.04347154, 11.10098215, 21.48490847, 18.03072836,
#        15.9270146 , 21.49374627, 14.58717741, 22.73683951, 19.44566195,
#        22.3541327 , 25.21664274, 25.17201214, 18.38488986, 16.6821552 ,
#        17.53549025, 30.94628678, 20.24580182, 24.32913515, 26.03700636,
#        14.16193562, 31.67405475, 42.16164344, 17.78541394, 27.15398414,
#        17.15619911, 13.89796881, 26.18324529, 20.31146497, 30.15442915,
#        21.40197681, 33.82519423, 15.70456024, 26.12212942, 39.32729512,
#        22.96554293, 18.91325954, 32.63194101, 24.98065976, 13.01265465,
#        22.62777898, 30.43093241, 31.73191476, 16.40355746, 20.98616672,
#        17.05303544, 20.31996315, 26.12630096, 30.76454442, 12.04820066,
#        20.61601402, 27.43590109, 11.00416618, 16.48923809, 24.02033793,
#         5.32627027, 21.48143996, 40.94039313, 18.21140137,  9.63091492,
#        21.30127893, 13.06900427, 21.49570513,  9.46458846, 23.07925296,
#        32.34892332, 18.88534902, 25.62683994, 29.13923562, 20.0115343 ,
#        25.76968651,  5.51145844, 20.0744615 , 15.44239721, 13.87232711,
#        20.73916832, 24.66174881, -0.2538889 , 13.69923384, 15.7331026 ,
#        22.25397203, 24.71497899, 10.80254981, 19.69633568, 23.65327906,
#        12.176328  , 18.50701366, 25.58783944, 20.98420425, 24.44716043,
#         7.70086666, 19.97600167, 21.96903965, 27.32711538, 32.19600359,
#        15.22099397, 34.42828276, 13.05226047, 21.13418522, 27.6881488 ,
#        15.85615837, 24.85605451,  3.17362602, 23.99821766, 25.93167233,
#        23.14391312, 25.04999783, 33.33290153, 20.82907372, 38.42695694,
#        13.97989867, 25.54419206, 17.80839951, 20.80841453, 10.02735169,
#        21.04717246, 22.38740664, 31.92215309, 31.36409018, 15.52754501,
#        16.92173868, 28.88229898, 24.78969715, 17.24710789,  6.1462204 ,
#        26.42694702, 23.69291497, 15.60878063, 13.49012171, 39.95880507,
#        16.68778731, 18.22972149])
