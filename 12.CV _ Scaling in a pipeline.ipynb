# %%
from sklearn.preprocessing import scale
import numpy as np, pandas as pd

# %%
boston = pd.read_csv('HousingData.csv')

# %%
boston.isnull().sum()
boston.fillna(method='ffill',inplace=True)

# %%
X = boston.drop('MEDV' , axis=1).values
y = boston['MEDV'].values

# %%
X_scaled = scale(X)

# %%
np.mean(X), np.std(X)
# Out:
# (70.09235981757372, 145.15345558206337)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
steps = [('scaler', StandardScaler()), ('knn', KNeighborsClassifier())]

# %%
pipeline = Pipeline(steps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8d4d728585ca> in <module>()
# ----> 1 pipeline = Pipeline(steps)
#
# NameError: name 'Pipeline' is not defined

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
knn_scaled = pipeline.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b69a5ceb53b5> in <module>()
# ----> 1 knn_scaled = pipeline.fit(X_train, y_train)
#
# NameError: name 'pipeline' is not defined

# %%
y_pred = pipeline.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a0c759197f3c> in <module>()
# ----> 1 y_pred = pipeline.predict(X_test)
#
# NameError: name 'pipeline' is not defined

# %%
accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b123e04c5193> in <module>()
# ----> 1 accuracy_score(y_test, y_pred)
#
# NameError: name 'accuracy_score' is not defined

# %%
knn_unscaled = KNeighborsClassifier().fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c0806ab2b224> in <module>()
# ----> 1 knn_unscaled = KNeighborsClassifier().fit(X_train, y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1138             self.outputs_2d_ = True
#    1139
# -> 1140         check_classification_targets(y)
#    1141         self.classes_ = []
#    1142         self._y = np.empty(y.shape, dtype=np.int)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'continuous'

# %%
knn_unscaled.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-de58e854fa74> in <module>()
# ----> 1 knn_unscaled.score(X_test, y_test)
#
# NameError: name 'knn_unscaled' is not defined

# %%
parameters = {knn__n_neighbors=np.arange(1, 50)}
# Out:
#   File "<ipython-input-21-86aa49f9432e>", line 1
#     parameters = {knn__n_neighbors=np.arange(1, 50)}
#                                   ^
# SyntaxError: invalid syntax

# %%
cv = GridSearchCV(pipeline, param_grid=parameters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f9380b8bd71c> in <module>()
# ----> 1 cv = GridSearchCV(pipeline, param_grid=parameters)
#
# NameError: name 'GridSearchCV' is not defined

# %%
cv.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6c976e20f457> in <module>()
# ----> 1 cv.fit(X_train, y_train)
#
# NameError: name 'cv' is not defined

# %%
y_pred = cv.predict(X__test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5609de4ff7e7> in <module>()
# ----> 1 y_pred = cv.predict(X__test)
#
# NameError: name 'cv' is not defined

# %%
print(cv.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a65616c5faa8> in <module>()
# ----> 1 print(cv.best_params_)
#
# NameError: name 'cv' is not defined

# %%
print(cv.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2af56c0f3a0e> in <module>()
# ----> 1 print(cv.score(X_test, y_test))
#
# NameError: name 'cv' is not defined

# %%
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e7622b950e3d> in <module>()
# ----> 1 print(classification_report(y_test, y_pred))
#
# NameError: name 'classification_report' is not defined
